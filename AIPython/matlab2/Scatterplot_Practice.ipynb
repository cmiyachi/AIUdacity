# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

def scatterplot_solution_1():
    sb.regplot(data=fuel_econ, x='city', y='highway', fit_reg=False)
    plt.xlabel('City MPG')
    plt.ylabel('Highway MPG')

def scatterplot_solution_2():
    bins_x = np.arange(0, fuel_econ['displ'].max() + 0.5, 0.5)
    bins_y = np.arange(0, fuel_econ['co2'].max() + 10, 10)
    plt.hist2d(data=fuel_econ, x='displ', y='co2', bins=[bins_x, bins_y], cmap='viridis_r')
    plt.colorbar(label='count')
    plt.xlabel('Displacement (l)')
    plt.ylabel('CO2 Emissions (g/mi)')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       5 import seaborn as sb
#       6
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#       8
# ----> 9 from solutions_biv import scatterplot_solution_1, scatterplot_solution_2
#
# ModuleNotFoundError: No module named 'solutions_biv'

# %% [markdown]
# In this workspace, you'll make use of this data set describing various car attributes, such as fuel efficiency. The cars in this dataset represent about 3900 sedans tested by the EPA from 2013 to 2018. This dataset is a trimmed-down version of the data found [here](https://video.udacity-data.com/topher/2018/April/5ac2907f_fuel-econ/fuel-econ.csv).

# %%
fuel_econ = pd.read_csv('../data/fuel_econ.csv')
fuel_econ.head()

# %% [markdown]
# ### **TO DO 1**:
# Let's look at the relationship between fuel mileage ratings for city vs. highway driving, as stored in the 'city' and 'highway' variables (in miles per gallon, or mpg). **Use a _scatter plot_ to depict the data.**
# 1. What is the general relationship between these variables?
# 2. Are there any points that appear unusual against these trends?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Expected Output

# %%
# run this cell to check your work against ours
scatterplot_solution_1()

# %% [markdown]
# ### **TO DO 2**:
# Let's look at the relationship between two other numeric variables. How does the engine size relate to a car's CO2 footprint? The 'displ' variable has the former (in liters), while the 'co2' variable has the latter (in grams per mile). **Use a heat map to depict the data.** How strong is this trend?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Expected Output

# %%
# run this cell to check your work against ours
scatterplot_solution_2()
