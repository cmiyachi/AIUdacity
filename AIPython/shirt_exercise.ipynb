# %% [markdown]
# <a href="https://colab.research.google.com/github/cmiyachi/AIUdacity/blob/main/AIPython/shirt_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use the Shirt Class
#
# You've seen what a class looks like and how to instantiate an object. Now it's your turn to write code that insantiates a shirt object.
#
# # Explanation of the Code
#
# This Jupyter Notebook is located in a folder called /`cd0184`/`ls12011`/`exercise-oop-syntax-practice-part-1`. You can access this folder by clicking the **Jupyter** logo at the top of the notebook. Inside the folder, you’ll find the following three files:
#
# - `shirt_exercise.ipynb`, which is the file you are currently looking at
# - `answer.py` containing answers to the exercise
# - `tests.py`, tests for checking your code - you can run these tests using the last code cell at the bottom of this notebook
#
# # Your Task
# The `shirt_exercise.ipynb` file, which you are currently looking at if you are reading this, has an exercise to help guide you through coding with an object in Python.
#
# Fill out the TODOs in each section of the Jupyter notebook. You can find a solution in the `answer.py` file.
#
# First, run this code cell below to load the `Shirt` class.

# %%
class Shirt:

    def __init__(self, shirt_color, shirt_size, shirt_style, shirt_price):
        self.color = shirt_color
        self.size = shirt_size
        self.style = shirt_style
        self.price = shirt_price

    def change_price(self, new_price):

        self.price = new_price

    def discount(self, discount):

        return self.price * (1 - discount)

# %%
### TODO:
#    - instantiate a shirt object with the following characteristics:
#        - color red, size S, style long-sleeve, and price 25
#    - store the object in a variable called shirt_one
#
#
###
shirt_one = Shirt('red', 'S', 'long-sleeve', 25)

# %%
### TODO:
#     - print the price of the shirt using the price attribute
#     - use the change_price method to change the price of the shirt to 10
#     - print the price of the shirt using the price attribute
#     - use the discount method to print the price of the shirt with a 12% discount
#
###
print(shirt_one.price)
shirt_one.change_price(10)
print(shirt_one.price)
print(shirt_one.discount(0.12))
# Out:
# 10
# 10
# 8.8

# %%
### TODO:
#
#    - instantiate another object with the following characteristics:
#        - color orange, size L, style short-sleeve, and price 10
#    - store the object in a variable called shirt_two
#
###
shirt_two = Shirt('orange', 'L', 'short-sleeve', 10)

# %%
### TODO:
#
#    - calculate the total cost of shirt_one and shirt_two
#    - store the results in a variable called total
#
###
total = shirt_one.price + shirt_two.price

# %%
### TODO:
#
#    - use the shirt discount method to calculate the total cost if
#       shirt_one has a discount of 14% and shirt_two has a discount
#       of 6%
#    - store the results in a variable called total_discounted
###
total_discounted = shirt_one.discount(0.14) + shirt_two.discount(0.06)

# %% [markdown]
# # Test Your Code
#
#
# The following code cell tests your code.
#
# There is a file called `tests.py` containing a function called `run_tests()`. The `run_tests()` function executes a handful of assert statements to check your work. You can see this file if you go to the Jupyter Notebook menu and click on **File → Open** and then open the `tests.py` file.
#
# Execute the next code cell. The code will produce an error if your answers in this exercise are not what was expected. Keep working on your code until all tests are passed.
#
# If you run the code cell and there is no output, then you passed all the tests!
#
# Additionally, as mentioned earlier, there is a solution file available. To access it, click the Jupyter logo at the top of the workspace, navigate to the /`cd0184`/`ls12011`/`exercise-oop-syntax-practice-part-1` folder, and open the solution file.

# %%
# Unit tests to check your solution
from tests import run_tests

run_tests(shirt_one, shirt_two, total, total_discounted)

# %% [markdown]
# # Task
# The user wants to implement the following:
# 1. In cell `8THV9FbfQQ2V`, print the current price of `shirt_one`, then change its price to 10, print the updated price, and finally print the price after a 12% discount.
# 2. In cell `YVZlIyQ-QQ2W`, instantiate a new `Shirt` object with color orange, size L, style short-sleeve, and price 10, storing it in `shirt_two`.
# 3. In cell `b4GdIzX4QQ2W`, calculate the total cost of `shirt_one` and `shirt_two` (using their current prices) and store the result in a variable called `total`.

# %% [markdown]
# ## Update Shirt One Details
#
# ### Subtask:
# Write code to print the current price of `shirt_one`, change its price to 10 using the `change_price` method, print the new price, and then print the price after a 12% discount using the `discount` method. This will be done in cell `8THV9FbfQQ2V`.

# %% [markdown]
# **Reasoning**:
# The subtask requires printing the initial price, changing it, printing the new price, and then printing a discounted price for 'shirt_one'. This can be achieved by writing a Python code block that interacts with the `shirt_one` object and its methods.

# %%
print(shirt_one.price)
shirt_one.change_price(10)
print(shirt_one.price)
print(shirt_one.discount(0.12))
# Out:
# 25
# 10
# 8.8

# %% [markdown]
# **Reasoning**:
# The next step is to instantiate a new `Shirt` object, as specified in the original task, in cell `YVZlIyQ-QQ2W`. This object will be named `shirt_two` and will have the characteristics: color orange, size L, style short-sleeve, and price 10.

# %%
shirt_two = Shirt('orange', 'L', 'short-sleeve', 10)

# %% [markdown]
# **Reasoning**:
# Following the previous step, the next task is to instantiate `shirt_two` with the specified attributes. This directly addresses the second part of the main task and corresponds to cell `YVZlIyQ-QQ2W`.

# %%
shirt_two = Shirt('orange', 'L', 'short-sleeve', 10)

# %% [markdown]
# **Reasoning**:
# The next step is to calculate the total cost of `shirt_one` and `shirt_two` by summing their current prices, as required by the third part of the main task in cell `b4GdIzX4QQ2W`.

# %%
total = shirt_one.price + shirt_two.price

# %% [markdown]
# **Reasoning**:
# The next step is to calculate the total cost of `shirt_one` and `shirt_two` by summing their current prices, as required by the third part of the main task in cell `b4GdIzX4QQ2W`.

# %%
total = shirt_one.price + shirt_two.price

# %% [markdown]
# ## Calculate Total Discounted Cost
#
# ### Subtask:
# Calculate the total cost if `shirt_one` has a 14% discount and `shirt_two` has a 6% discount, storing the result in `total_discounted`. This will be done in cell `W3-C2_8uQQ2X`.

# %% [markdown]
# **Reasoning**:
# The subtask requires calculating the total discounted cost of `shirt_one` and `shirt_two` using their respective `discount` methods and then summing them up to store in `total_discounted`.

# %%
total_discounted = shirt_one.discount(0.14) + shirt_two.discount(0.06)

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that all specified code blocks have been filled according to the instructions.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `shirt_one` object's initial price was \$25. It was successfully updated to \$10. After a 12% discount, its price became \$8.8.
# *   A new `Shirt` object, `shirt_two`, was successfully instantiated with attributes: color 'orange', size 'L', style 'short-sleeve', and price \$10.
# *   The `total` cost, calculated by summing the current prices of `shirt_one` (\$10) and `shirt_two` (\$10), was successfully stored.
# *   The `total_discounted` cost was successfully calculated by applying a 14% discount to `shirt_one` and a 6% discount to `shirt_two`, and then summing the discounted values.
#
# ### Insights or Next Steps
#
# *   The successful manipulation of shirt prices and the calculation of total and discounted costs indicate that the `Shirt` class methods (`change_price`, `discount`) and object instantiation are functioning correctly.
# *   To further validate the calculations, explicitly printing the `total` and `total_discounted` values in a future step would confirm their exact numerical results.
